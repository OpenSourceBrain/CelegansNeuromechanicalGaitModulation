# %%
# %matplotlib widget
from matplotlib import pyplot as plt


import WormView
# Out:
# Loaded data: (148, 500)
# Sz: 148, Nt: 500, Nbar: 49, NSEG: 48
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
